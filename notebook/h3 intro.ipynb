# %% [markdown]
# # H3 Intro

# %%
import h3
import pandas as pd
import folium
import branca.colormap as cm
import xml.etree.ElementTree as ET
from datetime import datetime

# %% [markdown]
# #### Set Coordinates and Resolution

# %%
lat = 39.73632141579045
lng = -104.9897890191563
resolution = 10

# %% [markdown]
# #### Convert Coordinates to H3

# %%
h3_index = h3.latlng_to_cell(lat, lng, resolution)
print(f"H3 Index: {h3_index}")
# Out:
# H3 Index: 8a268cda80dffff

# %% [markdown]
# #### Convert H3 to Coordinates

# %%
lat_lng = h3.cell_to_latlng(h3_index)
print(f"Latitude/Longitude: {lat_lng}")
# Out:
# Latitude/Longitude: (39.73594029216176, -104.98910346554506)

# %% [markdown]
# #### Convert H3 to Geometry Boundary

# %%
boundary = h3.cell_to_boundary(h3_index)
print(f"Boundary: {boundary}")
# Out:
# Boundary: ((39.73524428010972, -104.98900125244737), (39.73564964864881, -104.98824237067122), (39.73634565833955, -104.98834457890632), (39.7366362996269, -104.98920568004662), (39.736230928869034, -104.9899645663659), (39.73553491904265, -104.98986234700183))

# %% [markdown]
# #### Map the Boundary

# %%
# Create a map
m = folium.Map(location=[lat, lng], zoom_start=16)

# Add the H3 cell to the map
folium.Polygon(locations=boundary, color='red', weight=2).add_to(m)

# Save the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_266f88feb2313a62a07f2bf62a5c1112 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_266f88feb2313a62a07f2bf62a5c1112&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_266f88feb2313a62a07f2bf62a5c1112 = L.map(
#                 &quot;map_266f88feb2313a62a07f2bf62a5c1112&quot;,
#                 {
#                     center: [39.73632141579045, -104.9897890191563],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b392a9dc97143d72708c5e0ecc43e0f0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b392a9dc97143d72708c5e0ecc43e0f0.addTo(map_266f88feb2313a62a07f2bf62a5c1112);
#
#
#             var polygon_40e0973e58433a4620cf4cf78991b823 = L.polygon(
#                 [[39.73524428010972, -104.98900125244737], [39.73564964864881, -104.98824237067122], [39.73634565833955, -104.98834457890632], [39.7366362996269, -104.98920568004662], [39.736230928869034, -104.9899645663659], [39.73553491904265, -104.98986234700183]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_266f88feb2313a62a07f2bf62a5c1112);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Suunto gpx

# %%
# Fix for ET error: ensure ElementTree is imported
import xml.etree.ElementTree as ET

# %%
def parse_gpx_to_dataframe(gpx_file_path):
    """
    Parse a GPX file and convert it to a pandas DataFrame.
    Returns a DataFrame with columns: lat, lon, elevation, time, heart_rate
    """
    tree = ET.parse(gpx_file_path)
    root = tree.getroot()
    
    # Define namespaces
    namespaces = {
        'gpx': 'http://www.topografix.com/GPX/1/1',
        'gpxtpx': 'http://www.garmin.com/xmlschemas/TrackPointExtension/v1'
    }
    
    track_points = []
    
    # Find all track points
    for trkpt in root.findall('.//gpx:trkpt', namespaces):
        lat = float(trkpt.get('lat'))
        lon = float(trkpt.get('lon'))
        
        # Get elevation
        ele = trkpt.find('gpx:ele', namespaces)
        elevation = float(ele.text) if ele is not None else None
        
        # Get time
        time_elem = trkpt.find('gpx:time', namespaces)
        time_str = time_elem.text if time_elem is not None else None
        
        # Get heart rate from extensions
        hr_elem = trkpt.find('.//gpxtpx:hr', namespaces)
        heart_rate = int(hr_elem.text) if hr_elem is not None else None
        
        track_points.append({
            'lat': lat,
            'lon': lon,
            'elevation': elevation,
            'time': time_str,
            'heart_rate': heart_rate
        })
    
    df = pd.DataFrame(track_points)
    
    # Convert time to datetime
    if 'time' in df.columns:
        df['time'] = pd.to_datetime(df['time'])
    
    return df

# Parse the GPX file
gpx_df = parse_gpx_to_dataframe('../data/test/suunto_train_example.gpx')
print(f"GPX data shape: {gpx_df.shape}")
print(f"Columns: {gpx_df.columns.tolist()}")
gpx_df.head()
# Out:
# GPX data shape: (2132, 5)
# Columns: ['lat', 'lon', 'elevation', 'time', 'heart_rate']
#          lat       lon  elevation                      time  heart_rate
# 0  44.838780 -0.643135       27.8 2025-09-17 18:54:53+00:00          96
# 1  44.838772 -0.643102       27.8 2025-09-17 18:54:54+00:00          95
# 2  44.838762 -0.643058       27.8 2025-09-17 18:54:55+00:00          95
# 3  44.838747 -0.643015       27.8 2025-09-17 18:54:56+00:00          95
# 4  44.838737 -0.642967       27.8 2025-09-17 18:54:57+00:00          94

# %%
# Display basic statistics about the GPX data
print("GPX Data Summary:")
print(f"Total track points: {len(gpx_df)}")
print(f"Time range: {gpx_df['time'].min()} to {gpx_df['time'].max()}")
print(f"Duration: {gpx_df['time'].max() - gpx_df['time'].min()}")
print(f"Latitude range: {gpx_df['lat'].min():.6f} to {gpx_df['lat'].max():.6f}")
print(f"Longitude range: {gpx_df['lon'].min():.6f} to {gpx_df['lon'].max():.6f}")
print(f"Elevation range: {gpx_df['elevation'].min():.1f}m to {gpx_df['elevation'].max():.1f}m")
print(f"Heart rate range: {gpx_df['heart_rate'].min()} to {gpx_df['heart_rate'].max()} bpm")

# Check for missing values
print(f"\nMissing values:")
print(gpx_df.isnull().sum())
# Out:
# GPX Data Summary:
# Total track points: 2132
# Time range: 2025-09-17 18:54:53+00:00 to 2025-09-17 19:30:26+00:00
# Duration: 0 days 00:35:33
# Latitude range: 44.837590 to 44.840302
# Longitude range: -0.643135 to -0.599462
# Elevation range: 14.2m to 35.8m
# Heart rate range: 94 to 181 bpm
#
# Missing values:
# lat           0
# lon           0
# elevation     0
# time          0
# heart_rate    0
# dtype: int64

# %%
df_gpx = gpx_df[['lat', 'lon']].drop_duplicates()

df_gpx.to_csv('../data/gpx_treated_data.csv', index=False)

# %%
# Create a map showing the GPX track
# Calculate center point for the map
center_lat = gpx_df['lat'].mean()
center_lon = gpx_df['lon'].mean()

# Create the map
m = folium.Map(location=[center_lat, center_lon], tiles="Cartodb dark_matter", zoom_start=15)

# Add the track as a line
track_coords = list(zip(gpx_df['lat'], gpx_df['lon']))
folium.PolyLine(track_coords, color='red', weight=3, opacity=0.8).add_to(m)

# Add start and end markers
folium.Marker(
    location=[gpx_df['lat'].iloc[0], gpx_df['lon'].iloc[0]], 
    popup='Start', 
    icon=folium.Icon(color='green', icon='play')
).add_to(m)

folium.Marker(
    location=[gpx_df['lat'].iloc[-1], gpx_df['lon'].iloc[-1]], 
    popup='End', 
    icon=folium.Icon(color='red', icon='stop')
).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_
642], [44.83823, -0.640627], [44.838255, -0.640607], [44.838277, -0.640583], [44.838297, -0.640552], [44.838317, -0.640517], [44.838337, -0.640482], [44.838357, -0.640452], [44.83838, -0.64042], [44.838402, -0.64039], [44.838427, -0.640367], [44.838452, -0.640342], [44.83848, -0.64032], [44.838507, -0.640297], [44.838535, -0.640277], [44.838557, -0.640257], [44.838582, -0.640243], [44.838612, -0.640227], [44.838637, -0.640212], [44.838662, -0.640202], [44.83869, -0.640185], [44.838715, -0.640172], [44.838742, -0.640157], [44.838767, -0.640143], [44.838792, -0.640137], [44.83882, -0.640125], [44.838842, -0.640112], [44.83887, -0.640105], [44.838897, -0.640092], [44.838922, -0.640082], [44.838947, -0.640073], [44.838977, -0.640067], [44.839005, -0.640057], [44.839032, -0.640052], [44.83906, -0.640042], [44.839087, -0.640037], [44.839112, -0.640028], [44.839142, -0.64002], [44.839167, -0.640008], [44.839192, -0.640005], [44.83922, -0.639992], [44.839247, -0.639985], [44.839272, -0.63998], [44.8393, -0.639967], [44.839327, -0.63996], [44.839352, -0.639952], [44.83938, -0.639942], [44.839407, -0.639932], [44.839437, -0.639922], [44.839465, -0.639912], [44.839492, -0.639905], [44.839517, -0.639902], [44.839545, -0.639892], [44.839572, -0.639882], [44.839597, -0.639877], [44.839627, -0.639867], [44.839657, -0.639857], [44.839685, -0.639847], [44.839717, -0.639838], [44.839747, -0.6398

# %%
# Convert GPX track points to H3 indices
def add_h3_to_gpx_dataframe(df, resolution=10):
    """Add H3 index and boundaries to the GPX DataFrame"""
    h3_data = []
    for _, row in df.iterrows():
        lat = row['lat']
        lon = row['lon']
        h3_index = h3.latlng_to_cell(lat, lon, resolution)
        boundaries = h3.cell_to_boundary(h3_index)
        h3_data.append({
            'h3_index': h3_index,
            'h3_boundaries': boundaries
        })
    
    h3_df = pd.DataFrame(h3_data)
    return pd.concat([df, h3_df], axis=1)

# Add H3 data to the GPX DataFrame
gpx_df_with_h3 = add_h3_to_gpx_dataframe(gpx_df, resolution=9)

print("GPX DataFrame with H3 data:")
print(f"Shape: {gpx_df_with_h3.shape}")
print(f"Columns: {gpx_df_with_h3.columns.tolist()}")
print(f"Unique H3 cells: {gpx_df_with_h3['h3_index'].nunique()}")

# Show first few rows
gpx_df_with_h3[['lat', 'lon', 'elevation', 'heart_rate', 'h3_index']].head()
# Out:
# GPX DataFrame with H3 data:
# Shape: (2132, 7)
# Columns: ['lat', 'lon', 'elevation', 'time', 'heart_rate', 'h3_index', 'h3_boundaries']
# Unique H3 cells: 19
#          lat       lon  elevation  heart_rate         h3_index
# 0  44.838780 -0.643135       27.8          96  89186b6d86fffff
# 1  44.838772 -0.643102       27.8          95  89186b6d86fffff
# 2  44.838762 -0.643058       27.8          95  89186b6d86fffff
# 3  44.838747 -0.643015       27.8          95  89186b6d86fffff
# 4  44.838737 -0.642967       27.8          94  89186b6d86fffff

# %%
df_st_folium = gpx_df_with_h3[['h3_index', 'h3_boundaries']].drop_duplicates()

df_st_folium.to_csv('../data/app_csv_data.csv', index=False)

# %% [markdown]
# ## Real Data: 311 Calls about illegal parking in Denver, Colorado

# %% [markdown]
# #### Import and filter data

# %%
# Use gpx_df_with_h3 data
gpx_df_with_h3 = gpx_df_with_h3.dropna(subset=['lat', 'lon'])
gpx_df_with_h3.shape
# Out:
# (2132, 7)

# %%
gpx_df_with_h3 = gpx_df_with_h3[['h3_index']].drop_duplicates().reset_index(drop=True)
gpx_df_with_h3.shape

gpx_df_with_h3.to_csv('../data/gpx_treated_data.csv', index=False)

# %%
gpx_df_with_h3.head()
# Out:
#           h3_index
# 0  89186b6d86fffff
# 1  89186b6d867ffff
# 2  89186b6d863ffff
# 3  89186b6d82bffff
# 4  89186b6d823ffff

# %% [markdown]
# #### Visualize on a map

# %%
gpx_df_with_h3.head()
# Out:
#             h3_index                                      h3_boundaries
# 0    89186b6d86fffff  ((44.839922148484305, -0.6433260719029629), (4...
# 87   89186b6d867ffff  ((44.840299894806726, -0.6391638536919598), (4...
# 161  89186b6d863ffff  ((44.842837589023645, -0.6418529619431464), (4...
# 239  89186b6d82bffff  ((44.84067747455567, -0.6350017506271951), (44...
# 339  89186b6d823ffff  ((44.841054887744534, -0.630839762747802), (44...

# %%
# Use gpx_df_with_h3 data to visualize H3 cells on a map


m = folium.Map(location=[center_lat, center_lon], zoom_start=15, tiles="Cartodb dark_matter")

# Add the H3 cells to the map
for _, row in gpx_df_with_h3.iterrows():
    print(row['h3_boundaries'])
    boundaries = row['h3_boundaries']
    # Convert tuple of tuples to list of [lat, lon] for folium
    locations = [[lat, lon] for lat, lon in boundaries]
    folium.Polygon(
        locations=locations,
        color='#EFBF04',
        weight=1,
        fill=True,
        fill_opacity=0.5,
        popup=f"H3 Index: {row['h3_index']}"
    ).add_to(m)

# Display the map
m
# Out:
# ((44.839922148484305, -0.6433260719029629), (44.83882434727408, -0.6452045013732605), (44.83700660845641, -0.6447990734850095), (44.83628669409128, -0.6425153429869365), (44.83738447293523, -0.6406369880088075), (44.83920218850949, -0.6410422890367325))
# ((44.840299894806726, -0.6391638536919598), (44.83920218850949, -0.6410422890367325), (44.83738447293523, -0.6406369880088075), (44.83666448690879, -0.6383533784940029), (44.837762170846204, -0.6364750176553776), (44.83957986316881, -0.6368801918255591))
# ((44.842837589023645, -0.6418529619431464), (44.841739860363575, -0.6437314717912388), (44.839922148484305, -0.6433260719029629), (44.83920218850949, -0.6410422890367325), (44.840299894806726, -0.6391638536919598), (44.842117583440526, -0.6395691267102441))
# ((44.84067747455567, -0.6350017506271951), (44.83957986316881, -0.6368801918255591), (44.837762170846204, -0.6364750176553776), (44.83704211316928, -0.6341915291421264), (44.83813970220278, -0.6323131624638627), (44.83995737126546, -0.6327182097788961))
# ((44.841054887744534, -0.630839762747802), (44.83995737126546, -0.6327182097788961), (44.83813970220278, -0.6323131624638627), (44.837419572886205, -0.6300297949704213), (44.838517067018365, -0.6281514224733997), (44.840334712812904, -0.6285563429358836))

# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_85ee125b62743c2b228d07c221111542 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_85ee125b62743c2b228d07c221111542&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_85ee125b62743c2b228d07c221111542 = L.map(
#                 &quot;map_85ee125b62743c2b228d07c221111542&quot;,
#                 {
#                     center: [44.839164647748596, -0.62260675],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3e4b1555b4775a3332a7a3e6b4b500ea = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3e4b1555b4775a3332a7a3e6b4b500ea.addTo(map_85ee125b62743c2b228d07c221111542);
#
#
#             var polygon_110e8a58d024a03d8204b1c9723bc089 = L.polygon(
#                 [[44.839922148484305, -0.6433260719029629], [44.83882434727408, -0.6452045013732605], [44.83700660845641, -0.6447990734850095], [44.83628669409128, -0.6425153429869365], [44.83738447293523, -0.6406369880088075], [44.83920218850949, -0.6410422890367325]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#EFBF04&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#EFBF04&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_85ee125b62743c2b228d07c221111542);
#
#
#         var popup_e2b249da4d712a16dfd523c858939658 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_537b3a4f4d3abfa04c128eb085ebcc7e = $(`&lt;div id=&quot;html_537b3a4f4d3abfa04c128eb085ebcc7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;H3 Index: 89186b6d86fffff&lt;/div&gt;`)[0];
#                 popup_e2b249da4d712a16dfd523c858939658.setContent(html_537b3a4f4d3abfa04c128eb085ebcc7e);
#
#
#
#         polygon_110e8a58d024a03d8204b1c9723bc089.bindPopup(popup_e2b249da4d712a16dfd523c858939658)
#         ;
#
#
#
#
#             var polygon_8717b37d909ce9db6eecaf3a9f99f2eb = L.polygon(
#                 [[44.840299894806726, -0.6391638536919598], [44.83920218850949, -0.6410422890367325], [44.83738447293523, -0.6406369880088075], [44.83666448690879, -0.6383533784940029], [44.837762170846204, -0.6364750176553776], [44.83957986316881, -0.6368801918255591]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#EFBF04&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#EFBF04&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_85ee125b62743c2b228d07c221111542);
#
#
#         var popup_3daf5ea5b0a14fc10bfaeb68cdb84f1e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49d8c44916d042e427d3c2a09faaff02 = $(`&lt;div id=&quot;html_49d8c44916d042e427d3c2a09faaff02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;H3 Index: 89186b6d867ffff&lt;/div&gt;`)[0];
#                 popup_3daf5ea5b0a14fc10bfaeb68cdb84f1e.setContent(html_49d8c44916d042e427d3c2a09faaff02);
#
#
#
#         polygon_8717b37d909ce9db6eecaf3a9f99f2eb.bindPopup(popup_3daf5ea5b0a14fc10bfaeb68cdb84f1e)
#         ;
#
#
#
#
#             var polygon_9834d9ceff5e1c0b6bb027a67fed65c8 = L.polygon(
#                 [[44.842837589023645, -0.6418529619431464], [44.841739860363575, -0.6437314717912388], [44.839922148484305, -0.6433260719029629], [44.83920218850949, -0.6410422890367325], [44.840299894806726, -0.6391638536919598], [44.842117583440526, -0.6395691267102441]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#EFBF04&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#EFBF04&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;
